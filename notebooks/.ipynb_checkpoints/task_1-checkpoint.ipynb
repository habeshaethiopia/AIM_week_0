# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df=pd.read_csv('../data/benin-malanville.csv')

# %% [markdown]
# ## Summary Statistics:

# %%
df.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# 25%         0.000000      24.200000      28.800000       1.000000
# 50%         4.300000      28.000000      55.100000       1.900000
# 75%       447.900000      32.300000      80.100000       3.100000
# max      1342.300000      43.800000     100.000000      19.500000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        2.809195       0.473390     153.435172       8.582407
# std         2.029120       0.273395     102.332842       6.385864
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.300000       0.400000      59.000000       3.700000
# 50%         2.600000       0.500000     181.000000       8.600000
# 75%         4.100000       0.600000     235.100000      12.300000
# max        26.600000       4.200000     360.000000      99.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      994.197199       0.000923       0.001905      35.246026
# std         2.474993       0.030363       0.037115      14.807258
# min       985.000000       0.000000       0.000000       9.000000
# 25%       993.000000       0.000000       0.000000      24.200000
# 50%       994.000000       0.000000       0.000000      30.000000
# 75%       996.000000       0.000000       0.000000      46.900000
# max      1003.000000       1.000000       2.500000      81.000000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.471736       NaN
# std        12.348743       NaN
# min         8.100000       NaN
# 25%        23.600000       NaN
# 50%        28.900000       NaN
# 75%        41.500000       NaN
# max        72.500000       NaN

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)

# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print("Duplicate Rows:", duplicate_rows)

# Check data types of columns
data_types = df.dtypes
print("Data Types:\n", data_types)

# Check for invalid values

invalid_values = df.isin([0]).sum()
print("Invalid Values:\n", invalid_values)

# Check for missing values
missing_values = df[['GHI', 'DNI', 'DHI']].isnull().sum()
print("Missing Values:\n", missing_values)

# Check for outliers
outliers = df[['GHI', 'DNI', 'DHI']].apply(lambda x: x[(x - x.mean()).abs() > 3 * x.std()])
print("Outliers:\n", outliers)

# Check for incorrect entries
incorrect_entries = df[['GHI', 'DNI', 'DHI']].apply(lambda x: x[x < 0])
print("Incorrect Entries:\n", incorrect_entries)
# Out:
# Missing Values:
#  Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
# Duplicate Rows: 0
# Data Types:
#  Timestamp         object
# GHI              float64
# DNI              float64
# DHI              float64
# ModA             float64
# ModB             float64
# Tamb             float64
# RH               float64
# WS               float64
# WSgust           float64
# WSstdev          float64
# WD               float64
# WDstdev          float64
# BP                 int64
# Cleaning           int64
# Precipitation    float64
# TModA            float64
# TModB            float64
# Comments         float64
# dtype: object
# Invalid Values:
#  Timestamp             0
# GHI                 363
# DNI                5884
# DHI                 388
# ModA             245543
# ModB             245975
# Tamb                  0
# RH                    0
# WS                68187
# WSgust            64064
# WSstdev           64409
# WD                64412
# WDstdev           73096
# BP                    0
# Cleaning         525115
# Precipitation    521811
# TModA                 0
# TModB                 0
# Comments              0
# dtype: int64
# Missing Values:
#  GHI    0
# DNI    0
# DHI    0
# dtype: int64
# Outliers:
#             GHI  DNI    DHI
# 670        NaN  NaN  610.6
# 671     1274.0  NaN  615.2
# 672        NaN  NaN  612.8
# 673        NaN  NaN  593.2
# 674     1349.0  NaN  618.0
# ...        ...  ...    ...
# 524896     NaN  NaN  604.2
# 524900     NaN  NaN  591.5
# 524901     NaN  NaN  596.1
# 524916     NaN  NaN  599.5
# 524917     NaN  NaN  593.2
#
# [3811 rows x 3 columns]
# Incorrect Entries:
#          GHI  DNI  DHI
# 0      -1.2 -0.2 -1.1
# 1      -1.1 -0.2 -1.1
# 2      -1.1 -0.2 -1.1
# 3      -1.1 -0.1 -1.0
# 4      -1.0 -0.1 -1.0
# ...     ...  ...  ...
# 525595 -5.5 -0.1 -5.9
# 525596 -5.5 -0.1 -5.8
# 525597 -5.5 -0.1 -5.8
# 525598 -5.5 -0.1 -5.8
# 525599 -5.5 -0.1 -5.7
#
# [278722 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot GHI histogram
plt.subplot(2, 3, 1)
plt.hist(df['GHI'], bins=10)
plt.xlabel('GHI')
plt.ylabel('Frequency')
plt.title('GHI Histogram')

# Plot DNI histogram
plt.subplot(2, 3, 2)
plt.hist(df['DNI'], bins=10)
plt.xlabel('DNI')
plt.ylabel('Frequency')
plt.title('DNI Histogram')

# Plot DHI histogram
plt.subplot(2, 3, 3)
plt.hist(df['DHI'], bins=10)
plt.xlabel('DHI')
plt.ylabel('Frequency')
plt.title('DHI Histogram')

# Plot WS histogram
plt.subplot(2, 3, 4)
plt.hist(df['WS'], bins=10)
# Out:
# (array([2.64828e+05, 1.85047e+05, 6.50370e+04, 9.11600e+03, 1.02900e+03,
#         3.32000e+02, 1.51000e+02, 4.40000e+01, 1.30000e+01, 3.00000e+00]),
#  array([ 0.  ,  1.95,  3.9 ,  5.85,  7.8 ,  9.75, 11.7 , 13.65, 15.6 ,
#         17.55, 19.5 ]),
#  <BarContainer object of 10 artists>)
